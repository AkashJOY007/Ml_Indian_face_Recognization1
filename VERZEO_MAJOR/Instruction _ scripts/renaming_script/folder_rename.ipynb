# %%
import os

# %%
start_sequence = int(input('From where you want to start the sequence ? '))
# Out:
# From where you want to start the sequence ? 1251

# %%
for count,filename in enumerate(os.listdir("C:\Users\kunas\Downloads\ImageAssistant_Batch_Image_Downloader\www.google.com\2021-04-08_22-58-31\\rohit_sharma_-_Google_Search//")):
        dst ="indians-" + str(count+start_sequence) + ".jpg"
        src ='images/'+filename
        dst ='images/'+ dst
          
        # rename() function will
        # rename all the files
        os.rename(src, dst)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-22fdaadf4fd8> in <module>()
# ----> 1 for count,filename in enumerate(os.listdir("C:\\Users\\kunas\\Downloads\\ImageAssistant_Batch_Image_Downloader\\www.google.com\\2021-04-08_22-58-31\\rohit_sharma_-_Google_Search//")):
#       2         dst ="indians-" + str(count+start_sequence) + ".jpg"
#       3         src ='images/'+filename
#       4         dst ='images/'+ dst
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\kunas\\Downloads\\ImageAssistant_Batch_Image_Downloader\\www.google.com\\2021-04-08_22-58-31\\rohit_sharma_-_Google_Search//'
